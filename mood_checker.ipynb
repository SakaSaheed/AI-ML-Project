# %% [markdown]
# <a href="https://colab.research.google.com/github/SakaSaheed/AI-ML-Project/blob/main/mood_checker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome to Saheed Chatbot")
moods = ['happy', 'sad', 'tired', 'stressed', 'bored', 'angry', 'lonely']
activities = ["studying", "cooking", "resting", "streaming on tiktok", "exercising", "eating", "gaming", "listening to music"]
name = input("What's your name: ")
print(f"Welcome! {name}, Happy to meet you")
user_mood = input(f"How you feeling today: \n Please select from this options {moods} ").lower()
user_activity = input(f"In a simple word, what are you currently doing: \n Please select from this options {activities} ").lower()

if user_mood in moods:
    if user_activity in activities:
        if moods[0]== user_mood:
            if user_activity == activities[0]:
                print("You're doing great! Use that good energy to crush your study goals")
            elif user_activity == activities[1]:
                print("share the positive vibes along withe your food")
            elif user_activity == activities[2]:
                print("come on... go and play")
            elif user_activity == activities[3]:
                print("check our animal documentary")
            elif user_activity == activities[4]:
                print("That’s the spirit! Push a little extra than before")
            elif user_activity == activities[5]:
                print("Huh... make sure to add salt.")
            elif user_activity == activities[6]:
                print("Winning or losing, enjoy the ride — good vibes only!")
            elif user_activity == activities[7]:
                print("put a happy dancing while playing music ")

        elif moods[1] == user_mood:
            if user_activity == activities[0]:
                print("It's okay if focus is hard today and try taking a rest after some while.")
            elif user_activity == activities[1]:
                print("make sure to do well on the food, that way you can be happy even if it's just a bit.")
            elif user_activity == activities[2]:
                print("Yeah, you should rest.  Rest heals!")
            elif user_activity == activities[3]:
                print("keep streaming... next post will make your day ")
            elif user_activity == activities[4]:
                print("Gentle movement helps lift your mood. Try a walk or some stretches ")
            elif user_activity == activities[5]:
                print("come on... Eat the meal on time and take some rest")
            elif user_activity == activities[6]:
                print("Winning or losing, enjoy the ride!")
            elif user_activity == activities[7]:
                print("Sad playlist? Go for it. Then shift to something more hopeful")

        elif moods[2] == user_mood:
            if user_activity == activities[0]:
                print("Maybe pause and stretch a bit... Studying can wait a few minutes.")
            elif user_activity == activities[1]:
                print("Try playing music while cooking")
            elif user_activity == activities[2]:
                print("Yes! Just rest. You earned it ")
            elif user_activity == activities[3]:
                print("Be mindful of screen fatigue")
            elif user_activity == activities[4]:
                print("Light stretching might be better than a full workout today  ")
            elif user_activity == activities[5]:
                print("come on... Eat the meal on time and take some rest")
            elif user_activity == activities[6]:
                print("play again when you lose... till you win")
            elif user_activity == activities[7]:
                print("Try calm music to rest your mind")

        elif moods[3] == user_mood:
            if user_activity == activities[0]:
                print("Maybe pause and stretch a bit... Studying can wait a few minutes.")
            elif user_activity == activities[1]:
                print("Try cooking and take a nap")
            elif user_activity == activities[2]:
                print("Yes! Just rest. you'll feel better after")
            elif user_activity == activities[3]:
                print("Maybe watch calming or funny content ")
            elif user_activity == activities[4]:
                print("Sweat out the stress... it really works.")
            elif user_activity == activities[5]:
                print("come on... Eat the meal on time and take some rest")
            elif user_activity == activities[6]:
                print("Play something fun and low-pressure")
            elif user_activity == activities[7]:
               print("soft instrumentals or nature sounds help calm your nerves")

        elif moods[4] == user_mood:
            if user_activity == activities[0]:
                print("study in a new spot or use a fun quiz app ")
            elif user_activity == activities[1]:
                print("Try playing music while cooking ")
            elif user_activity == activities[2]:
                print("Yes! Just rest. you'll feel better after")
            elif user_activity == activities[3]:
                print("Maybe create your own TikTok!")
            elif user_activity == activities[4]:
                print("Try a new workout playlist or dance challenge")
            elif user_activity == activities[5]:
                print("come on... Eat the meal on time and try doing something fun")
            elif user_activity == activities[6]:
                print("Try a new game")
            elif user_activity == activities[7]:
                print("Shuffle your playlist ")

        elif moods[5] == user_mood:
            if user_activity == activities[0]:
                print("studying angry never ends well...Take a short break before you continue ")
            elif user_activity == activities[1]:
                print("Just chill ")
            elif user_activity == activities[2]:
                print("Close your eyes for a bit — sometimes all you need is a reset ")
            elif user_activity == activities[3]:
                print("scroll for cute baby videos...it helps")
            elif user_activity == activities[4]:
                print("Channel that fire into your workout")
            elif user_activity == activities[5]:
                print("angry eating never ends well...so eat slowing.")
            elif user_activity == activities[6]:
                print("Play something that lets you release tension...but avoid competitive games for now!")
            elif user_activity == activities[7]:
                print("Switch to chill tunes ")
        elif moods[6] == user_mood:
            if user_activity == activities[0]:
                print("Try studying with a friend online or join a study stream")
            elif user_activity == activities[1]:
                print("watch some cooking techniques ")
            elif user_activity == activities[2]:
                print("Take a nap and call a friend")
            elif user_activity == activities[3]:
                print("Go live on Tiktok")
            elif user_activity == activities[4]:
                print("Take a friend along to the gym")
            elif user_activity == activities[5]:
                print("call in a friend")
            elif user_activity == activities[6]:
                print("Hop into a multiplayer game ")
            elif user_activity == activities[7]:
                print("Switch to party music ")
    else:
        print("write a valid activity, e.g"); print(activities)
else:
    print("write a valid mood, e.g"); print(moods)
# Out:
# Welcome to Saheed Chatbot
# What's your name: saheed
# Welcome! saheed, Happy to meet you
# How you feeling today:
#  Please select from this options ['happy', 'sad', 'tired', 'stressed', 'bored', 'angry', 'lonely'] happy
# In a simple word, what are you currently doing:
#  Please select from this options ['studying', 'cooking', 'resting', 'streaming on tiktok', 'exercising', 'eating', 'gaming', 'listening to music'] studying
# You're doing great! Use that good energy to crush your study goals
