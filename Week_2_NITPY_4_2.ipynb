# %% [markdown]
# <a href="https://colab.research.google.com/github/SakaSaheed/AI-ML-Project/blob/main/Week_2_NITPY_4_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# A = P(1+r/n)^nt
principal = float(input("Enter starting money: "))
rate = float(input("Enter interest rate: "))
number_of_times_compounded = int(input("Enter compound frequency: "))
time = float(input("enter number of years: "))

amount = principal * ((1 + (rate/number_of_times_compounded)) ** (number_of_times_compounded * time))
print(f"Total amount: {amount - principal}")z
# Out:
# Enter starting money: 30000
# Enter interest rate: 26.5
# Enter compound frequency: 12
# enter number of years: 3
# Total amount: 5.048735969979354e+22

# %%
age = 22
if age >= 18:
  print(2)
# Out:
# 2

# %%
bank_balance = 2000000
if bank_balance > 20000000:
  print("Get a black card today")

# %%
teacher_around = True
classroom_available = False
time_reasonable = True
asuu_strike = True
teacher_busy = False
clashing_classes = True

# if teacher_around == True and asuu_strike == False:
#   print("Class is happening")

if classroom_available == True and clashing_classes == False:
  print("There is class today")

# %%
bank_balance = 1000
if bank_balance <= 10000:
  print("Go and buy garri")
# Out:
# Go and buy garri

# %%
there_is_credit_alert = False
if there_is_credit_alert:
  print("Salary seen")
else:
  print("Hang tight")
# Out:
# Hang tight

# %%
gift = "Biscuit"
score = 80

if score > 75:
  print(f"Take your {gift}")
else:
  print("Try again next semester")
# Out:
# Take your Biscuit

# %%
has_free_food = True
if has_free_food:
  print("I'll be there")
else:
  print("Leave me alone")
# Out:
# I'll be there

# %%
want_peace = False
if want_peace:
  print("Have some peace")
else:
  print("Problem always")
# Out:
# Problem always

# %%
attendance = 100

if attendance > 90:
  print("Present")
elif attendance > 90:
  print("Somewhat present")
else:
  print("Are you still a student")
# Out:
# Present

# %%
hunger_level = 4

if hunger_level > 8 and hunger_level < 10:
  print("You need fufu immediately")
elif hunger_level > 5 and hunger_level < 7:
  print("Lets make noodles")
elif hunger_level < 5:
  print("Take some cornflakes")
else:
  print("Are you even human?")
# Out:
# Take some cornflakes

# %%
alert = "tax"

if alert == "debit":
  print("Billing again, God abeg")
elif alert == "credit":
  print("Guy you don hammer")
else:
  print("What's that")
# Out:
# What's that

# %%
game = input("Enter your game: ").lower()
if game == "call of duty":
  print("You are a tactical guy")
elif game == "gta":
  print("Everything is possible")
elif game == "chess":
  print("Mastermind!")
elif game == "candy crush":
  print("Passing time")
elif game == "among us":
  print("where is your child")
else:
  print("game not in database")
# Out:
# Enter your game: gy
# game not in database

# %%
mood = input("how are you feeling? ").lower()

if mood == "sad":
  print("Go to a comedy show")
elif mood == "happy":
  print("Do giveaway")
elif mood == "angry" or mood == "hungry":
  print("Calm down and get some food")
elif mood == "moody" or mood == "anxious":
  print("Listen to music and pray")
else:
  print("Just sleep")
# Out:
# how are you feeling? tired
# Just sleep

# %%
has_a_dog = True
if has_a_dog is True:
  print("Baba yega")
# Out:
# Baba yega

# %%
name = "John Wick"
second_name = "John Wicke"

if name is name:
  print("hello john")
# Out:
# hello john

# %%
gpa = 4.5
income = 10000
if gpa > 4.0:
  if income > 20000:
    print("Not eligible")
  else:
    print("Eligible")
# Out:
# Eligible

# %%
new_user = input("Are you a new user (y/n)? ").lower()
restaurant = input("Choose your shop: ").lower()
if new_user == "y":
  if restaurant == "chicken republic":
    print("Get 50% discount")
  else:
    print("Get 20% discount")
elif new_user == "n":
  if restaurant == "chicken republic":
    print("Get 30% discount")
  else:
    print("Sorry o, only chicken republic")
else:
  print("Get no discount, you fraud")
# Out:
# Are you a new user (y/n)? hack
# Choose your shop: chicken republic
# Get no discount, you fraud

# %%
jamb_score = 270
post_utme = 30

if jamb_score > 250:
  if jamb_score > 300 and post_utme > 18:
    print("Medicine is in your path")
  elif jamb_score >= 270 and post_utme > 15:
    print("Agba Engineer")
  else:
    print("Engineering is not the end of the world")
else:
  if jamb_score > 200:
    print("There is fishery")
  else:
    print("Try polytechnics or come next year")
# Out:
# Agba Engineer

# %%
name = "Matthew"
id(name)
# Out:
# 133766837208432

# %%
times_called = "amarachi ruth"
half_of_10 = "amarachi ruth"
id(times_called) == id(half_of_10)
times_called is half_of_10

if times_called == half_of_10:
  print("yes")
# Out:
# yes

# %%
print(id(True))
is_everything = True
id(is_everything)
# Out:
# 10557792
# 10557792

# %%
is_fisherman = False
id(False) == id(is_fisherman)
if is_fisherman is False:
  print("fish")
# Out:
# fish

# %%
team = input("Enter your team: ").lower()
match team:
  case "real madrid":
    print("15 times champions league winner")
  case "chelsea":
    print("World champions")
  case "manchester united":
    print("20 times champions league winner")
  case "arsenal":
    print("Come back next season")
  case _:
    print("You dont matter or wrong input")

# %%
price_change = -5

match price_change:
  case 10:
    print("To the moon")
  case 0:
    print("Prayers up")
  case -5:
    print("Delete binance")
# Out:
# Delete binance
